# %% [markdown]
# <a href="https://colab.research.google.com/github/dusandraq/Machine-Learning-Homework/blob/main/testcode.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = "Hello World"
print(f'Can you say {a}')
# Out:
# Can you say Hello World
